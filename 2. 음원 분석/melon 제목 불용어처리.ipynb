# %% [markdown]
# ### melon 데이터 제목 가수 불용어 정리

# %%
- 제대로 된 검색을 위한 정리

RandB = pd.read_csv('RandB.csv')

RandB[RandB['song_name'].isnull()]

artist_name = RandB['artist_name_basket']
song_na = RandB['song_name']
song_id = RandB['id']

song_na
artist_name
song_id

result = pd.concat([song_id,song_na,artist_name], axis=1)

result

import nltk
import re
from tqdm import tqdm_notebook as tq

result["artist_name_basket"] = result["artist_name_basket"].str.replace(pat=r'[^\w]', repl=r'', regex=True)

result

### regex = "\(.*\)|\s-\s.*"
### new = re.sub(regex,'', result['song_name'][0])
### new

regex = "\(.*\)|\s-\s.*"
new_song_na = []
for i in range(0,47218):
    re_name = re.sub(regex,'', str(result['song_name'][i]))
    new_song_na.append(re_name)
new_song_na

new_sname = pd.DataFrame(new_song_na)

new_sname

result = pd.concat([song_id,new_sname,artist_name], axis=1)

result

result["artist_name_basket"] = result["artist_name_basket"].str.replace(pat=r'[^\w]', repl=r'', regex=True)

result.columns = ['id','song_name','artist_name']

spo_data=result

spo_data['song_name'] = spo_data['song_name'].str.strip()

spo_data['artist_name'] = spo_data['artist_name'].str.strip()

spo_data.to_csv('spo_data.csv')

# %% [markdown]
# ### 네오소울 100곡 모음

# %%
import pandas as pd
import numpy as np

# %%
neo_artist = ["D'Angelo", 
              "Jill Scott",
              "Erykah Badu",
              "Maxwell",
              "Tony Toni Tone", 
              "Musiq", 
              "D'Angelo",
          'India Arie', 
              "Lauryn Hill",
              'Erykah Badu' ,
'Bilal',  
'Goapele',  
'Digable Planets',  
'Common',
'Anthony Hamilton',
'Mos Def' ,
'Les Nubians',  
'John Legend' ,
'Alicia Keys'  ,
'Angie Stone'  ,
'Dwele',
'Jill Scott' , 
'Mary J. Blige',  
'Floetry'  ,
"Me'shell Ndeg'ecello",
'Maxwell'  ,
'Bilal'  ,
'Raheem Devaughn'  ,
'Anothony Hamilton'  ,
'Alicia Keys'  ,
'Dionne Farris'  ,
'Musiq ' ,
'Floetry'  ,
"D'Angelo" ,
'Kemistry'  ,
'Amel Larrieux'  ,
'Robin Thicke'  ,
'Chrisette Michelle'  ,
'The Roots'  ,
'Lauryn Hill' ,
'Eric Benet' ,
'Adriana Evans'  ,
'Maxwell'  ,
'Andre 3000'  ,
'Erykah Badu' ,
'Blackstar'  ,
'Glenn Lewis'  ,
'Rahsaan Patterson'  ,
'Foreign Exchange'  ,
'Jill Scott' ,
'Vivan Green'  ,
'Dwele'  ,
'Kindred the Family'  ,
'Rapheal Saadiq'  ,
'Eric Roberson',
"D'Angelo",
'John Legend',
'Angie Stone' ,
'Corinne Bailey Rae'  ,
'Rapheal Saadiq'  ,
'Amy Winehouse'  ,
'Elisabeth Withers'  ,
'Heather Headley'  ,
'Chrisette Michelle'  ,
'Raheem Devaughn'  ,
'Adele' ,
'Blackstar'  ,
'Lesdisi'  ,
'Vivian Green'  ,
'Gaelle'  ,
'Eric Roberson'  ,
'Algebra'  ,
'Goapele'  ,
'Leela James'  ,
'Van Hunt'  ,
'Joss Stone'  ,
'Gaelle'  ,
'Jazzyfatnastees'  ,
'Lalah Hathaway'  ,
'Corinne Bailey Rae'  ,
'Kemistry'  ,
'Soul Sista'  ,
'Julie Dexter'  ,
'Dwele'  ,
'Chico Debarge'  ,
'Lucy Pearl'  ,
'Lyfe' ,
'The Roots'  ,
'Allen Anothony'  ,
'Dave Hollister'  ,
'Trina Broussard'  ,
'The Refugee Camp'  ,
'Dwele'  ,
'Van Hunt'  ,
'Donnie'  ,
'Jazzhole'  ,
'Jaquar Wright', 'Zhane','Christion', 'Dwele', 'Georgia Anne Muldrow']

neo_song_name = ["Brown Sugar", "A Long Walk", "Otherside of the game", "Sumthin Sumthin", "Lay your head on my pillow","Mary Go Round", "Untitled",
               "Brown Skin", "Nothing Even Matters", 'On&ON',
'Soul Sista',
'Closer',
'Rebirth of Slick',
'Come Close',
"Where I'm From",
'Umi Says',
'Makeda',
'Ordinary People',
'Butterflies',
'Brotha',
'Subject',
'The Way',
'My Life',
'Say Yes',
'Fool of Me',              
'Fortunate',
'Sometime',
'You',
'Charlene',
"You don't know my name",
'Hopeless',
'Just Friends',
'Lay Down',
'Me and those dreamin eyez of mine',
'Love Calls',
'Get Up',
'Lost Without You',
'Epiphany',
'You got me',
'Killin me Softly',
'Georgy Pordgy',
'Seeing is believing',
'Whenever, Wherever, Whatever "Live"',
'Prototype',
'Telephone',
'K.O.S.  Determination',
"Don't you forget it",
'Where you are',
'Sincere',
'Whatever, Whatever',
'Emotional Roller Coaster',
'Find a way',
'Far Away',
'Still Ray',
'Pretty Girl',
'Jonz in my bonz',
'Heaven Only Knows',
"I wish I didn't miss you",
'Like a Star',
'You should be here',
'You sent me flying',
'Be with You',
'He Is',
'Your Joy',
'Woman',
'Hometown Glory',
'Thieves in the Night',
'Alright',
'What is Love',
'Fallin',
'I love you too much',
'At this time',
'Different',
'Music',
'Seconds of Pleasure',
'Spoiled',
'Fade Away',
'Breakthrough',
'Let Go',
'Enchantment',
"I can't stop loving you",
'Bilal',
'Venusian',
"I'm Cheatin'",
'Iggin Me',
'I want to dance tonight',
'Never Never land',
'Hypnotic',
'Alright',
'One woman man',
'Inside my love',
'Sweetest Thing',
'Vain',
'Down here in hell',
'If I were you',
'Wintersky',
'Told Ya',
"Off My Mind",'Full Of Smoke','I understand','Simple Advice']


neo_artist

neo_song_name

neo_artist = pd.DataFrame(neo_artist)
neo_song_name= pd.DataFrame(neo_song_name)

neosoul = pd.concat([neo_artist,neo_song_name], axis=1)

neosoul.columns = ['artist_name','song_name']

neosoul.info()

pd.options.display.max_rows = None

neosoul

neosoul['artist_name'] = neosoul['artist_name'].str.strip()

neosoul['song_name']= neosoul['song_name'].str.strip()

neosoul

neosoul.to_csv('neosoul.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0
' Stevie Wonder',
' Marvelettes',
' Mary Wells',
' Martha & The Vandellas',
' Contours',
' Marvin Gaye',
' Marvin Gaye & Tammi Terrell',
' Smokey Robinson & The Miracles',
' Jr. Walker & The All Stars',
' Jackson 5',
' Supremes',
' Temptations',
' Stevie Wonder',
' Four Tops',
' Smokey Robinson & The Miracles',
' Supremes',
' Miracles',
' Temptations',
' Four Tops',
' Stevie Wonder',
' Marvin Gaye & Tammi Terrell',
' Barrett Strong',
' Eddie Holland',
' Miracles',
' Supremes',
' Supremes',
' Lionel Richie & Diana Ross',
' Stevie Wonder',
' Miracles',
' Martha & The Vandellas',
' Marvin Gaye & Kim Weston',
' Edwin Starr',
' Smokey Robinson & The Miracles',
' Rick James',
' Stevie Wonder',
' Gladys Knight & The Pips',
' Stevie Wonder',
' Temptations',
' Temptations',
' Temptations',
' Temptations',
' Undisputed Truth',
' Isley Brothers',
' Jimmy Ruffin',
' Marvin Gaye',
' Marvin Gaye',
' Marvelettes',
' Martha & The Vandellas',
' Marvelettes',
' Temptations',
' Thelma Houston',
' Lionel Richie',
'Smokey Robinson & The Miracles',
' Stevie Wonder',
' Mary Wells',
' Gladys Knight & The Pips',
' Diana Ross',
' Diana Ross',
' Commodores',
' Temptations',
'Marvelettes',
' Marvelettes',
' Four Tops',
' Rockwell',
' Lionel Richie',
' Four Tops',
' Brenda Holloway',
' Eddie Holland',
' Marvin Gaye & Tammi Terrell',
' Martha & The Vandellas',
' Martha & The Vandellas',
' Eddie Kendricks',
' Velvelettes',
' Junior Walker & The All',
' Jackson 5',
' Diana Ross',
' Rick James',
' Smokey Robinson',
' David Ruffin',
' Commodores',
' Bonnie Pointer/The Elgins',
' Dazz Band',
' Spinners',
' Originals',
' Originals',
' Velvelettes',
' Marv Johnson',
' Teena Marie',
' Jackson 5',
' Jr. Walker',
' Shorty Long',
' Bobby Taylor & The Vancouvers',
' Monitors/Valadiers']

# %%
motown_artist

motown_song_name

motown_artist = pd.DataFrame(motown_artist)
motown_song_name= pd.DataFrame(motown_song_name)

motown = pd.concat([motown_artist,motown_song_name], axis=1)

motown.columns = ['artist_name','song_name']

motown.info()

pd.options.display.max_rows = None

motown

motown['artist_name'] = motown['artist_name'].str.strip()

motown['song_name']= motown['song_name'].str.strip()

motown
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   artist_name  100 non-null    object
#  1   song_name    100 non-null    object
# dtypes: object(2)
# memory usage: 1.7+ KB
#                        artist_name  \
# 0                      Marvin Gaye
# 1                      Temptations
# 2                        Four Tops
# 3                         Supremes
# 4                      Marvin Gaye
# 5           Martha & The Vandellas
# 6                        Jackson 5
# 7                    Stevie Wonder
# 8                      Marvelettes
# 9                       Mary Wells
# 10          Martha & The Vandellas
# 11                        Contours
# 12                     Marvin Gaye
# 13     Marvin Gaye & Tammi Terrell
# 14  Smokey Robinson & The Miracles
# 15      Jr. Walker & The All Stars
# 16                       Jackson 5
# ...

# %%
motown.to_csv('motown.csv')
